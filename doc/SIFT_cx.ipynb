# %%
#!pip install opencv-python==3.4.2.16
#!pip install opencv-contrib-python==3.4.2.16

import cv2 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img1 = cv2.imread('images/0001.jpg', cv2.IMREAD_GRAYSCALE)  
img2 = cv2.imread('images/0002.jpg', cv2.IMREAD_GRAYSCALE) 
#img1 = cv2.imread('images/0001.jpg')
#gray1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)

# %% [markdown]
# #sift
# sift = cv2.xfeatures2d.SIFT_create()
# #keypoints_1, descriptors_1 = sift.detectAndCompute(gray1, None)

# %% [markdown]
# #pic1 = cv2.drawKeypoints(gray1, keypoints_1, img1)

# %% [markdown]
# #plt.imshow(pic1)

# %%
#sift
sift = cv2.xfeatures2d.SIFT_create()

# %%
keypoints_1, descriptors_1 = sift.detectAndCompute(img1, None)
keypoints_2, descriptors_2 = sift.detectAndCompute(img2, None)

# %% [markdown]
# len(keypoints_1), len(keypoints_2)

# %%
pic1 = cv2.drawKeypoints(img1, keypoints_1, None)
pic2 = cv2.drawKeypoints(img2, keypoints_2, None)
plt.imshow(pic2)

# %% [markdown]
# import pip

# %% [markdown]
# !type pip

# %% [markdown]
# #cv2.__version__
